# %%
# Aufgabe 2.1
"""
a) omega = {1,2,3,4,...,12}
b) A = 2^12 = 4096
"""

# Aufgabe 2.1.2
"""
A={1,3,5..,9,11}, B={2}, C = {2,3}, D = (/)

Vereinbar: A Schnitt B != 0
unvereinbar: A Schnitt B = 0

a) unvereinbar, der schnitt ist leer
b) vereinbar, schnitt = 2
c) unvereinbar, schnitt ist leer
d) unvereinbar, schnitt ist leer

"""

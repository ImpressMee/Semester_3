# %% [markdown]
# ### Versuch 1, Praktikum Technische Grundlagen der künstlichen Intelligenz
#
# In diesem versuch werden Daten eines abstandsmessers gesammelt, ausgelesen, berechnet und genormt durch lineare Regression.
#
# Protokollierung:

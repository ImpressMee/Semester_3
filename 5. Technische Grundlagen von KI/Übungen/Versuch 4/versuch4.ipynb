# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
'''
TODO: Hier alle Imports die Relevant sind
TODO: Eventuell auch hier die Methoden fürs Plotten Implementieren. Also Globale Funktionen
'''
# Out:
# '\nTODO: Hier alle Imports die Relevant sind\nTODO: Eventuell auch hier die Methoden fürs Plotten Implementieren. Also Globale Funktionen\n'

# %% [markdown]
# ----
# # Aufgabe 1
# ----
#
# ![image.png](attachment:image.png)

# %%
'''
TODO: Implement a dynamically CVS-Read routine and read the CSV in the Data Folder
TODO: Glätte die Sprungantwort via np.convolve mit der Fensterbreite 50 um sie Nummerisch zu differenzieren
'''
# Out:
# '\nTODO: Implement a dynamically CVS-Read routine and read the CSV in the Data Folder\nTODO: Glätte die Sprungantwort via np.convolve mit der Fensterbreite 50 um sie Nummerisch zu differenzieren\n'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
TODO: die funktion numpy.gradient auf die Nummerische differentation anwenden welche davor berechnet wurde
'''
# Out:
# '\nTODO: die funktion numpy.gradient auf die Nummerische differentation anwenden welche davor berechnet wurde\n'

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Beispiel wie so ein Bode-Diagramm aussieht:
#
# ![image-2.png](attachment:image-2.png)

# %%
'''
TODO: Fouriertransformation auf die Impulsantwort Anwenden für den Frequenzgang, numpy.fft.fft() https://numpy.org/devdocs/reference/generated/numpy.fft.fft.html
TODO: Die ergebnisse der Fouriertransformation (u, t) dann in ein Bode-Diagramm Plotten (frequenz in HZ) (sehe vorherhigen Versuch für genauere Details)
TODO: Ermittelte Resonanzfrequenz mit der theoretischen vorhersage vergleichen (f_res = 1/2*PI*math.sqrt(L*C)), 
      wobei: L = Induktivität der Spule (in Henry, H), C Kapazität des Kondensators (in farad, F) ist
'''
# Out:
# '\nTODO: Fouriertransformation auf die Impulsantwort Anwenden für den Frequenzgang, numpy.fft.fft() https://numpy.org/devdocs/reference/generated/numpy.fft.fft.html\nTODO: Die ergebnisse der Fouriertransformation (u, t) dann in ein Bode-Diagramm Plotten (frequenz in HZ) (sehe vorherhigen Versuch für genauere Details)\nTODO: Ermittelte Resonanzfrequenz mit der theoretischen vorhersage vergleichen (f_res = 1/2*PI*math.sqrt(L*C)), \n      wobei: L = Induktivität der Spule (in Henry, H), C Kapazität des Kondensators (in farad, F) ist\n'

# %% [markdown]
# -----
# # Aufgabe 2
# -----

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
TODO: Schreibe eine Routine welche das Musikstück einliest, welches im DATA Ordner liegt.
TODO: Schneide ein 10-Sekunden abschnitt raus
TODO: Schreibe eine Plot Routine, welche dieses 10-Sekunden Stück als Kurve und als Spektrogramm darstellt.
'''
# Out:
# '\nTODO: Schreibe eine Routine welche das Musikstück einliest, welches im DATA Ordner liegt.\nTODO: Schneide ein 10-Sekunden abschnitt raus\nTODO: Schreibe eine Plot Routine, welche dieses 10-Sekunden Stück als Kurve und als Spektrogramm darstellt.\n'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
